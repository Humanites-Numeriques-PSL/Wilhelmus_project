# %%
import pandas as pd

# %%
df = pd.read_csv('./top20authors.csv')
dfTo = pd.read_csv('./../features/FINAL_TRAIN.csv')

# %%
listeToComp = df['Unnamed: 0'].values.tolist()

# %%
listeToComp
# Out:
# ['Karel van Mander',
#  'C. J. Wits',
#  'Leenaert Clock',
#  'Hermanus van den Burg',
#  'Joan Ysermans',
#  'Hendrick Jansz. Prins',
#  'Justus de Harduwijn',
#  'Jan Jansz. Deutel',
#  'Frans vander Straten de jongere',
#  'Zacharias Heyns',
#  'Aegidius Haeffacker',
#  'Haerlem Soetendal',
#  'Michiel Vlack',
#  'Pieter Brughman',
#  'Guillaume Abrahams Ooijevaer',
#  'Jan Zoet',
#  'Pieter de Bisschop',
#  'Christianus de Placker',
#  'Boudewijn Jansen Wellens',
#  'Jacobus Viverius']

# %%
dfTo
dfFinal = dfTo[dfTo['auteurs'].isin(listeToComp)]
dfFinal
# Out:
#         index  n_v_pron  pron_n_v  adp_pron_n  adp_art_n  v_pron_n   n_adv_v  \
# 23      26482  0.018182  0.012440    0.011483   0.022010  0.006699  0.010526
# 53     161812  0.008696  0.008696         NaN   0.008696  0.017391       NaN
# 55      26457  0.014085  0.014085    0.004695   0.004695  0.014085  0.018779
# 114     21234  0.006803       NaN         NaN   0.006803  0.020408  0.006803
# 133      6709  0.018711  0.027027    0.018711   0.004158  0.012474  0.006237
# ...       ...       ...       ...         ...        ...       ...       ...
# 11059   20570  0.005208  0.005208         NaN   0.005208  0.015625  0.010417
# 11060    6744  0.026087  0.026087         NaN        NaN  0.026087  0.017391
# 11074    9947  0.010204  0.015306    0.005102   0.015306  0.015306  0.010204
# 11077   20550  0.022222  0.008333    0.019444   0.011111  0.013889  0.011111
# 11081    9565  0.016484  0.005495    0.038462   0.010989       NaN  0.005495
#
#         n_adp_n   art_n_v  adv_v_pron  ...        om        nu       wel  \
# 23     0.014354  0.009569    0.010526  ...  0.009124  0.003650  0.001825
# 53     0.017391  0.017391    0.008696  ...       NaN       NaN       NaN
# 55     0.009390  0.014085    0.023474  ...       NaN       NaN       NaN
# 114    0.006803  0.013605    0.013605  ...  0.026667       NaN       NaN
# 133    0.018711  0.004158    0.014553  ...  0.003876  0.003876  0.003876
# ...         ...       ...         ...  ...       ...       ...       ...
# 11059  0.005208  0.010417    0.010417  ...       NaN  0.022989       NaN
# 11060       NaN  0.008696    0.043478  ...  0.017857       NaN       NaN
# 11074  0.020408  0.010204    0.005102  ...       NaN       NaN  0.009524
# 11077  0.008333  0.016667    0.013889  ...  0.015625  0.015625  0.020833
# 11081  0.010989       NaN    0.005495  ...  0.019048       NaN       NaN
#
#             ons     haten      deze       wat       dit       bij  \
# 23     0.005474  0.003650  0.010949  0.001825  0.005474  0.001825
# 53          NaN  0.018519       NaN       NaN  0.018519       NaN
# 55          NaN       NaN       NaN       NaN       NaN       NaN
# 114         NaN       NaN       NaN  0.026667       NaN       NaN
# 133         NaN       NaN       NaN       NaN       NaN  0.007752
# ...         ...       ...       ...       ...       ...       ...
# 11059       NaN       NaN  0.034483       NaN  0.011494       NaN
# 11060       NaN       NaN       NaN       NaN  0.017857       NaN
# 11074       NaN  0.009524       NaN  0.009524  0.019048  0.009524
# 11077       NaN  0.010417       NaN  0.005208  0.020833  0.005208
# 11081       NaN       NaN  0.019048       NaN       NaN       NaN
#
#                             auteurs
# 23                 Karel van Mander
# 53           Christianus de Placker
# 55                 Karel van Mander
# 114    Guillaume Abrahams Ooijevaer
# 133             Justus de Harduwijn
# ...                             ...
# 11059                 Joan Ysermans
# 11060           Justus de Harduwijn
# 11074              Karel van Mander
# 11077                    C. J. Wits
# 11081         Hendrick Jansz. Prins
#
# [1286 rows x 150 columns]

# %%
dfFinal2.to_csv('FrequenceTop20.csv', index=False)

# %%
dfFinal2 = dfFinal.T
dfFinal2
# Out:
#                        23                      53                55     \
# index                  26482                  161812             26457
# n_v_pron            0.018182                0.008696          0.014085
# pron_n_v             0.01244                0.008696          0.014085
# adp_pron_n          0.011483                     NaN          0.004695
# adp_art_n            0.02201                0.008696          0.004695
# ...                      ...                     ...               ...
# deze                0.010949                     NaN               NaN
# wat                 0.001825                     NaN               NaN
# dit                 0.005474                0.018519               NaN
# bij                 0.001825                     NaN               NaN
# auteurs     Karel van Mander  Christianus de Placker  Karel van Mander
#
#                                    114                  133    \
# index                              21234                 6709
# n_v_pron                        0.006803             0.018711
# pron_n_v                             NaN             0.027027
# adp_pron_n                           NaN             0.018711
# adp_art_n                       0.006803             0.004158
# ...                                  ...                  ...
# deze                                 NaN                  NaN
# wat                             0.026667                  NaN
# dit                                  NaN                  NaN
# bij                                  NaN             0.007752
# auteurs     Guillaume Abrahams Ooijevaer  Justus de Harduwijn
#
#                                143       144                  146    \
# index                          20276     21039                14427
# n_v_pron                    0.004386  0.016393                  NaN
# pron_n_v                    0.008772       NaN             0.020833
# adp_pron_n                  0.017544  0.005464             0.020833
# adp_art_n                   0.008772  0.005464                  NaN
# ...                              ...       ...                  ...
# deze                        0.007874       NaN                  NaN
# wat                              NaN       NaN                  NaN
# dit                              NaN       NaN                  NaN
# bij                              NaN       NaN                  NaN
# auteurs     Boudewijn Jansen Wellens  Jan Zoet  Aegidius Haeffacker
#
#                             157                     159    ...  \
# index                        9530                  151859  ...
# n_v_pron                 0.020408                 0.03125  ...
# pron_n_v                 0.006803                     NaN  ...
# adp_pron_n               0.013605                  0.0625  ...
# adp_art_n                0.017007                     NaN  ...
# ...                           ...                     ...  ...
# deze                          NaN                     NaN  ...
# wat                           NaN                     NaN  ...
# dit                           NaN                     NaN  ...
# bij                           NaN                     NaN  ...
# auteurs     Hendrick Jansz. Prins  Christianus de Placker  ...
#
#                                       11030       11031             11039  \
# index                                 14165       20525             26836
# n_v_pron                           0.011111    0.019074          0.010638
# pron_n_v                           0.011111    0.024523          0.006383
# adp_pron_n                         0.013889    0.013624          0.012766
# adp_art_n                          0.016667    0.008174          0.010638
# ...                                     ...         ...               ...
# deze                                    NaN    0.005376               NaN
# wat                                0.005076         NaN               NaN
# dit                                0.010152    0.016129          0.004202
# bij                                     NaN    0.005376               NaN
# auteurs     Frans vander Straten de jongere  C. J. Wits  Karel van Mander
#
#                        11040             11055          11059  \
# index                 180538              9912          20570
# n_v_pron            0.017442          0.017157       0.005208
# pron_n_v            0.011628          0.022059       0.005208
# adp_pron_n          0.023256          0.022059            NaN
# adp_art_n           0.011628          0.017157       0.005208
# ...                      ...               ...            ...
# deze                0.013889          0.005051       0.034483
# wat                      NaN               NaN            NaN
# dit                      NaN          0.005051       0.011494
# bij                      NaN          0.005051            NaN
# auteurs     Karel van Mander  Karel van Mander  Joan Ysermans
#
#                           11060             11074       11077  \
# index                      6744              9947       20550
# n_v_pron               0.026087          0.010204    0.022222
# pron_n_v               0.026087          0.015306    0.008333
# adp_pron_n                  NaN          0.005102    0.019444
# adp_art_n                   NaN          0.015306    0.011111
# ...                         ...               ...         ...
# deze                        NaN               NaN         NaN
# wat                         NaN          0.009524    0.005208
# dit                    0.017857          0.019048    0.020833
# bij                         NaN          0.009524    0.005208
# auteurs     Justus de Harduwijn  Karel van Mander  C. J. Wits
#
#                             11081
# index                        9565
# n_v_pron                 0.016484
# pron_n_v                 0.005495
# adp_pron_n               0.038462
# adp_art_n                0.010989
# ...                           ...
# deze                     0.019048
# wat                           NaN
# dit                           NaN
# bij                           NaN
# auteurs     Hendrick Jansz. Prins
#
# [150 rows x 1286 columns]
