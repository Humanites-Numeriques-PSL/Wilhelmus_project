# %%
import pandas as pd

# %%
df = pd.read_csv('./../svm_out/FINAL_PREDICTIONS.csv')

# %%
df = df.T

# %%
df
# Out:
#                                 0               1            2     \
# Unnamed: 0                         0               1            2
# filename                       19437          118464        36216
# author              Jan van der Veen  Willem Sluiter  Joannes Mys
# A. de R. en J.G.           -1.949989       -2.301208    -2.388889
# A.C. Alberts               -1.368177       -1.122567    -1.424977
# ...                              ...             ...          ...
# Willem de Swaen            -4.010523       -4.393758    -1.731639
# Willem van Geldof          -1.189585       -1.530816    -1.503772
# Wolterus ter Burgh         -1.944374       -0.888082    -1.667934
# Wouter Robbertz            -1.408494       -1.423031    -1.236128
# Zacharias Heyns            -2.262348       -1.267757    -1.381201
#
#                                   3                4                  5     \
# Unnamed: 0                           3                4                  5
# filename                        180196           182537              20409
# author              Joannes Vollenhove  Carolus Tuinman  Cornelis Maertsz.
# A. de R. en J.G.             -1.309083        -2.281595          -1.788134
# A.C. Alberts                 -1.433298        -1.139574          -1.442699
# ...                                ...              ...                ...
# Willem de Swaen              -2.023841        -3.356602          -2.525275
# Willem van Geldof            -1.549922        -1.517096          -1.354912
# Wolterus ter Burgh           -1.752384        -1.769199          -2.231011
# Wouter Robbertz              -1.355002        -1.061176           -1.51151
# Zacharias Heyns              -2.022495        -1.392788          -2.504334
#
#                                 6                  7     \
# Unnamed: 0                         6                  7
# filename                      175170              36622
# author              Jan Pieter Heije  Cornelis Maertsz.
# A. de R. en J.G.           -2.375538          -1.547103
# A.C. Alberts                -1.30288          -1.669488
# ...                              ...                ...
# Willem de Swaen            -2.065544          -3.745672
# Willem van Geldof          -1.641313          -1.993244
# Wolterus ter Burgh         -1.492545          -1.648425
# Wouter Robbertz            -1.339255          -1.428353
# Zacharias Heyns            -2.353668          -1.598766
#
#                                          8                      9     ...  \
# Unnamed: 0                                  8                      9  ...
# filename                                 2897                 180364  ...
# author              Dirk Rafaelsz. Camphuysen  Gaudentius van Loemel  ...
# A. de R. en J.G.                    -2.124271              -2.522633  ...
# A.C. Alberts                        -1.341553              -1.474286  ...
# ...                                       ...                    ...  ...
# Willem de Swaen                     -0.982444              -2.661602  ...
# Willem van Geldof                   -1.362626              -1.199219  ...
# Wolterus ter Burgh                  -1.795137              -1.632425  ...
# Wouter Robbertz                     -1.042567              -1.274682  ...
# Zacharias Heyns                     -1.904268              -0.826192  ...
#
#                                 1223       1224                        1225  \
# Unnamed: 0                      1223       1224                        1225
# filename                      120233     162609                       21113
# author              A. de R. en J.G.  F. Pitton  Hendrik Jacobz. Soetenboom
# A. de R. en J.G.           -0.484542  -1.572379                   -3.159129
# A.C. Alberts               -1.154357  -1.292825                   -1.447356
# ...                              ...        ...                         ...
# Willem de Swaen            -2.540326  -0.807039                    -2.07679
# Willem van Geldof          -1.523526  -1.435305                   -1.266885
# Wolterus ter Burgh         -2.169953  -1.701287                   -1.512716
# Wouter Robbertz            -1.263948  -0.928293                   -1.214167
# Zacharias Heyns             -2.32239  -1.730679                    -1.05804
#
#                                 1226              1227                  1228  \
# Unnamed: 0                      1226              1227                  1228
# filename                       13366            192785                113714
# author              Karel van Mander  Jacob Westerbaen  Guilielmus Bolognino
# A. de R. en J.G.           -2.373326         -1.113581             -1.698941
# A.C. Alberts               -1.445927         -1.545559             -1.421392
# ...                              ...               ...                   ...
# Willem de Swaen            -1.630663          -1.69654             -3.115987
# Willem van Geldof          -1.173323         -1.767527             -1.772815
# Wolterus ter Burgh         -1.942702         -1.286607             -1.050673
# Wouter Robbertz             -1.46875         -1.650258             -1.505674
# Zacharias Heyns             -1.83052         -1.978716             -0.912619
#
#                           1229              1230                1231  \
# Unnamed: 0                1229              1230                1231
# filename                 20509            191469               36610
# author              C. J. Wits  Jacob Westerbaen  Lucas van Mechelen
# A. de R. en J.G.     -2.120867         -1.530108           -1.505334
# A.C. Alberts         -1.501259          -1.33555           -1.615269
# ...                        ...               ...                 ...
# Willem de Swaen      -1.711646         -1.947822           -2.364434
# Willem van Geldof    -1.474174         -1.467328           -1.710713
# Wolterus ter Burgh   -2.241868         -1.331664           -1.713983
# Wouter Robbertz        -1.7118          -1.46439           -1.341459
# Zacharias Heyns      -1.596266         -1.357038            -1.82183
#
#                                 1232
# Unnamed: 0                      1232
# filename                        5135
# author              Karel van Mander
# A. de R. en J.G.           -2.333788
# A.C. Alberts                  -1.459
# ...                              ...
# Willem de Swaen             -2.54728
# Willem van Geldof          -1.780813
# Wolterus ter Burgh          -1.98484
# Wouter Robbertz             -1.31841
# Zacharias Heyns            -1.002091
#
# [238 rows x 1233 columns]

# %%
df.iloc[:,1232]
# Out:
# Unnamed: 0                        1232
# filename                          5135
# author                Karel van Mander
# A. de R. en J.G.             -2.333788
# A.C. Alberts                    -1.459
#                             ...
# Willem de Swaen               -2.54728
# Willem van Geldof            -1.780813
# Wolterus ter Burgh            -1.98484
# Wouter Robbertz               -1.31841
# Zacharias Heyns              -1.002091
# Name: 1232, Length: 238, dtype: object

# %%
df = df.iloc[:,1232]

# %%
df2 = df.drop(['Unnamed: 0', 'filename', 'author'])
df2 = df2.sort_values(ascending=False)
df2 = df2.iloc[:30]
df2
# Out:
# Karel van Mander                    0.09623
# C. J. Wits                        -0.783447
# Leenaert Clock                    -0.787453
# Hermanus van den Burg             -0.807077
# Joan Ysermans                     -0.877217
# Hendrick Jansz. Prins             -0.917138
# Justus de Harduwijn               -0.961572
# Jan Jansz. Deutel                 -0.964094
# Frans vander Straten de jongere   -0.995545
# Zacharias Heyns                   -1.002091
# Aegidius Haeffacker               -1.013492
# Haerlem Soetendal                 -1.015488
# Michiel Vlack                     -1.029794
# Pieter Brughman                   -1.053942
# Guillaume Abrahams Ooijevaer      -1.054242
# Jan Zoet                          -1.071264
# Pieter de Bisschop                -1.075868
# Christianus de Placker            -1.085352
# Boudewijn Jansen Wellens          -1.094389
# Jacobus Viverius                  -1.123647
# Name: 1232, dtype: object

# %%
df2.to_csv()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_48324/2000566219.py in <module>
# ----> 1 df_sorted = df.sort_values(by=['1232'])
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6257
#    6258             by = by[0]
# -> 6259             k = self._get_label_or_level_values(by, axis=axis)
#    6260
#    6261             # need to rewrap column in Series to apply key function
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: '1232'
