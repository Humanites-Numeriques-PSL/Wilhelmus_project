# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./../features/FINAL_TEST.csv')

# %%
df
# Out:
#        index  n_v_pron  pron_n_v  adp_pron_n  adp_art_n  v_pron_n   n_adv_v  \
# 0      19437  0.015873  0.019841    0.003968   0.019841  0.011905  0.003968
# 1     118464  0.019231  0.012238    0.020979   0.012238  0.006993  0.006993
# 2      36216       NaN  0.017391    0.030435        NaN  0.004348  0.013043
# 3     180196       NaN  0.004405    0.013216   0.017621  0.013216  0.013216
# 4     182537       NaN       NaN         NaN        NaN       NaN       NaN
# ...      ...       ...       ...         ...        ...       ...       ...
# 1228  113714  0.018692  0.004673    0.009346   0.018692  0.004673  0.014019
# 1229   20509  0.030717  0.010239    0.013652   0.010239  0.027304  0.003413
# 1230  191469  0.016667  0.016667    0.050000   0.016667  0.016667  0.016667
# 1231   36610  0.008772  0.021930    0.021930   0.013158  0.008772       NaN
# 1232    5135  0.020794  0.015123    0.007561   0.007561  0.015123  0.005671
#
# ...

# %%
dfWil = df.loc[1232]
dfWil
# Out:
# index               5135
# n_v_pron        0.020794
# pron_n_v       0.0151229
# adp_pron_n    0.00756144
# adp_art_n     0.00756144
#                  ...
# deze                 NaN
# wat                  NaN
# dit             0.004329
# bij             0.004329
# auteurs        Wilhelmus
# Name: 1232, Length: 150, dtype: object

# %%
dfWil = dfWil[1:149]
dfWil
# Out:
# n_v_pron        0.020794
# pron_n_v       0.0151229
# adp_pron_n    0.00756144
# adp_art_n     0.00756144
# v_pron_n       0.0151229
#                  ...
# haten                NaN
# deze                 NaN
# wat                  NaN
# dit             0.004329
# bij             0.004329
# Name: 1232, Length: 148, dtype: object

# %%
dfWil = dfWil.astype(float)

# %%
dfWil
# Out:
# n_v_pron      0.020794
# pron_n_v      0.015123
# adp_pron_n    0.007561
# adp_art_n     0.007561
# v_pron_n      0.015123
#                 ...
# haten              NaN
# deze               NaN
# wat                NaN
# dit           0.004329
# bij           0.004329
# Name: 1232, Length: 148, dtype: float64

# %%
dfWil.to_csv("FeaturesWilhelmus.csv")
